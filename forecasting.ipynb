# %%
import streamlit as st
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# %%
st.title("Sales Forecast")

@st.cache
def load_data():
    data = pd.read_csv("sales_data.csv")
    return data

data = load_data()

st.write("Preview of the sales data:")
st.write(data.head())
# Out:
# 2023-02-11 22:11:32.913
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/lib/python3/dist-packages/ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     359             # Hash the input
# --> 360             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     361
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     625             assert code is not None
# --> 626             if self._file_should_be_hashed(code.co_filename):
#     627                 context = _get_context(obj)
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     401         return file_util.file_is_in_folder_glob(
# --> 402             filepath, self._get_main_script_directory()
#     403         ) or file_util.file_in_pythonpath(filepath)
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _get_main_script_directory()
#     713         # script path in ScriptRunner.
# --> 714         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715         return str(abs_main_path.parent)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# /tmp/ipykernel_25960/1201097854.py in <module>
#      10     return data
#      11
# ---> 12 data = load_data()
#      13
#      14 st.write("Preview of the sales data:")
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py in wrapped_func(*args, **kwargs)
#     713         if show_spinner:
#     714             with spinner(message):
# --> 715                 return get_or_create_cached_value()
#     716         else:
#     717             return get_or_create_cached_value()
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py in get_or_create_cached_value()
#     635                 # If we generated the key earlier we would only hash those
#     636                 # globals by name, and miss changes in their code or value.
# --> 637                 cache_key = _hash_func(non_optional_func, hash_funcs)
#     638
#     639             # First, get the cache that's attached to this function.
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py in _hash_func(func, hash_funcs)
#     765     # because this step will be hashing any objects referenced in the function
#     766     # body.
# --> 767     update_hash(
#     768         func,
#     769         hasher=func_hasher,
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     106
#     107     ch = _CodeHasher(hash_funcs)
# --> 108     ch.update(hasher, val, context)
#     109
#     110
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in update(self, hasher, obj, context)
#     383     def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     384         """Update the provided hasher with the hash of an object."""
# --> 385         b = self.to_bytes(obj, context)
#     386         hasher.update(b)
#     387
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     372
#     373         except Exception as ex:
# --> 374             raise InternalHashError(ex, obj)
#     375
#     376         finally:
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     358         try:
#     359             # Hash the input
# --> 360             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     361
#     362             # Hmmm... It's possible that the size calculation is wrong. When we
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     624             code = getattr(obj, "__code__", None)
#     625             assert code is not None
# --> 626             if self._file_should_be_hashed(code.co_filename):
#     627                 context = _get_context(obj)
#     628                 defaults = getattr(obj, "__defaults__", None)
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     400             return False
#     401         return file_util.file_is_in_folder_glob(
# --> 402             filepath, self._get_main_script_directory()
#     403         ) or file_util.file_in_pythonpath(filepath)
#     404
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _get_main_script_directory()
#     712         # This works because we set __main__.__file__ to the
#     713         # script path in ScriptRunner.
# --> 714         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715         return str(abs_main_path.parent)
#     716
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x7fbdd28305e0>
# ```
#
# Please see the `hash_funcs` [documentation](https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.

# %%
import streamlit as st
import pandas as pd
from sklearn.ensemble import RandomForestRegressor

# %%
data = load_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     359             # Hash the input
# --> 360             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     361
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     625             assert code is not None
# --> 626             if self._file_should_be_hashed(code.co_filename):
#     627                 context = _get_context(obj)
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     401         return file_util.file_is_in_folder_glob(
# --> 402             filepath, self._get_main_script_directory()
#     403         ) or file_util.file_in_pythonpath(filepath)
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _get_main_script_directory()
#     713         # script path in ScriptRunner.
# --> 714         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715         return str(abs_main_path.parent)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# /tmp/ipykernel_25960/2366623734.py in <module>
# ----> 1 data = load_data()
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py in wrapped_func(*args, **kwargs)
#     713         if show_spinner:
#     714             with spinner(message):
# --> 715                 return get_or_create_cached_value()
#     716         else:
#     717             return get_or_create_cached_value()
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py in get_or_create_cached_value()
#     635                 # If we generated the key earlier we would only hash those
#     636                 # globals by name, and miss changes in their code or value.
# --> 637                 cache_key = _hash_func(non_optional_func, hash_funcs)
#     638
#     639             # First, get the cache that's attached to this function.
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/caching.py in _hash_func(func, hash_funcs)
#     765     # because this step will be hashing any objects referenced in the function
#     766     # body.
# --> 767     update_hash(
#     768         func,
#     769         hasher=func_hasher,
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     106
#     107     ch = _CodeHasher(hash_funcs)
# --> 108     ch.update(hasher, val, context)
#     109
#     110
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in update(self, hasher, obj, context)
#     383     def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     384         """Update the provided hasher with the hash of an object."""
# --> 385         b = self.to_bytes(obj, context)
#     386         hasher.update(b)
#     387
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     372
#     373         except Exception as ex:
# --> 374             raise InternalHashError(ex, obj)
#     375
#     376         finally:
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in to_bytes(self, obj, context)
#     358         try:
#     359             # Hash the input
# --> 360             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     361
#     362             # Hmmm... It's possible that the size calculation is wrong. When we
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _to_bytes(self, obj, context)
#     624             code = getattr(obj, "__code__", None)
#     625             assert code is not None
# --> 626             if self._file_should_be_hashed(code.co_filename):
#     627                 context = _get_context(obj)
#     628                 defaults = getattr(obj, "__defaults__", None)
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _file_should_be_hashed(self, filename)
#     400             return False
#     401         return file_util.file_is_in_folder_glob(
# --> 402             filepath, self._get_main_script_directory()
#     403         ) or file_util.file_in_pythonpath(filepath)
#     404
#
# ~/.local/lib/python3.10/site-packages/streamlit/runtime/legacy_caching/hashing.py in _get_main_script_directory()
#     712         # This works because we set __main__.__file__ to the
#     713         # script path in ScriptRunner.
# --> 714         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715         return str(abs_main_path.parent)
#     716
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x7fbdd28305e0>
# ```
#
# Please see the `hash_funcs` [documentation](https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.

# %%
data = pd.read_csv("sales_data.csv")

# %%
model = RandomForestRegressor()
model.fit(data.drop(columns='sales'), data['sales'])

forecast_periods = st.slider("Select the number of forecast periods:", min_value=1, max_value=24, value=12, step=1)

forecast = model.predict(data.drop(columns='sales').tail(forecast_periods))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_25960/285470132.py in <module>
#       1 model = RandomForestRegressor()
# ----> 2 model.fit(data.drop(columns='sales'), data['sales'])
#       3
#       4 forecast_periods = st.slider("Select the number of forecast periods:", min_value=1, max_value=24, value=12, step=1)
#       5
#
# ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     329         if issparse(y):
#     330             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331         X, y = self._validate_data(
#     332             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333         )
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
#     597             out = X, y
#     598
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1072         )
#    1073
# -> 1074     X = check_array(
#    1075         X,
#    1076         accept_sparse=accept_sparse,
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854                     array = array.astype(dtype, casting="unsafe", copy=False)
#     855                 else:
# --> 856                     array = np.asarray(array, order=order, dtype=dtype)
#     857             except ComplexWarning as complex_warning:
#     858                 raise ValueError(
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    2062
#    2063     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064         return np.asarray(self._values, dtype=dtype)
#    2065
#    2066     def __array_wrap__(
#
# ValueError: could not convert string to float: '01/01/2020'

# %%
st.write("Forecast results:")
st.write(forecast)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_25960/2606281074.py in <module>
#       1 model = RandomForestRegressor()
# ----> 2 model.fit(data.drop(columns='sales'), data['sales'])
#       3
#       4 forecast_periods = st.slider("Select the number of forecast periods:", min_value=1, max_value=24, value=12, step=1)
#       5
#
# ~/.local/lib/python3.10/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     329         if issparse(y):
#     330             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 331         X, y = self._validate_data(
#     332             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     333         )
#
# ~/.local/lib/python3.10/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     594                 y = check_array(y, input_name="y", **check_y_params)
#     595             else:
# --> 596                 X, y = check_X_y(X, y, **check_params)
#     597             out = X, y
#     598
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1072         )
#    1073
# -> 1074     X = check_array(
#    1075         X,
#    1076         accept_sparse=accept_sparse,
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854                     array = array.astype(dtype, casting="unsafe", copy=False)
#     855                 else:
# --> 856                     array = np.asarray(array, order=order, dtype=dtype)
#     857             except ComplexWarning as complex_warning:
#     858                 raise ValueError(
#
# ~/.local/lib/python3.10/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    2062
#    2063     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2064         return np.asarray(self._values, dtype=dtype)
#    2065
#    2066     def __array_wrap__(
#
# ValueError: could not convert string to float: '01/01/2020'

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# load the data
df = pd.read_csv("sales_data.csv")

df = df.dropna()

# %%
# convert the date column to datetime
df['date'] = pd.to_datetime(df['date'])

# extract additional features
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['day_of_week'] = df['date'].dt.dayofweek
#df['previous_month_sales'] = df['sales'].shift(1)

df = df.fillna(0)

# split the data into training and test sets
train_df, test_df = train_test_split(df, test_size=0.2)

# define the features and target
#features = ['year', 'month', 'day', 'day_of_week','previous_month_sales']
features = ['year', 'month', 'day', 'day_of_week']

target = 'sales'

# train the random forest model
model = RandomForestRegressor()
model.fit(train_df[features], train_df[target])

# make predictions on the test set
predictions = model.predict(test_df[features])

# evaluate the model
mae = mean_absolute_error(test_df[target], predictions)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 12.866666666666665

# %%
# convert the date column to datetime
df['date'] = pd.to_datetime(df['date'])

# extract additional features
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day'] = df['date'].dt.day
df['day_of_week'] = df['date'].dt.dayofweek
df['previous_month_sales'] = df['sales'].shift(1)

df = df.fillna(0)

# split the data into training and test sets
train_df, test_df = train_test_split(df, test_size=0.2)

# define the features and target
features = ['year', 'month', 'day', 'day_of_week','previous_month_sales']
target = 'sales'

# train the random forest model
model = RandomForestRegressor()
model.fit(train_df[features], train_df[target])

# make predictions on the test set
predictions = model.predict(test_df[features])

# evaluate the model
mae = mean_absolute_error(test_df[target], predictions)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 11.333333333333343

# %%
df
# Out:
#          date  sales  year  month  day  day_of_week  previous_month_sales
# 0  2020-01-01  100.0  2020      1    1            2                   NaN
# 1  2020-01-02  120.0  2020      1    2            3                 100.0
# 2  2020-01-03  130.0  2020      1    3            4                 120.0
# 3  2020-01-04  140.0  2020      1    4            5                 130.0
# 4  2020-01-05  150.0  2020      1    5            6                 140.0
# 5  2020-01-06  165.0  2020      1    6            0                 150.0
# 6  2020-01-07  180.0  2020      1    7            1                 165.0
# 7  2020-01-08  190.0  2020      1    8            2                 180.0
# 8  2020-01-09  205.0  2020      1    9            3                 190.0
# 9  2020-01-10  215.0  2020      1   10            4                 205.0
# 10 2020-01-11  230.0  2020      1   11            5                 215.0
# 11 2020-01-12  240.0  2020      1   12            6                 230.0

# %%
df['date'] = pd.to_datetime(df['date'])

# extract additional features
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data['day_of_week'] = data['date'].dt.dayofweek
data['previous_month_sales'] = data['sales'].shift(-1)

# define the features and target
features = ['year', 'month', 'day', 'day_of_week','previous_month_sales']
target = 'sales'

# train the random forest model
model = RandomForestRegressor()
model.fit(train_data[features], train_data[target])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_25960/1340786190.py in <module>
#      14 # train the random forest model
#      15 model = RandomForestRegressor()
# ---> 16 model.fit(train_data[features], train_data[target])
#
# NameError: name 'train_data' is not defined

# %%
test_df
# Out:
#         date  sales  year  month  day  day_of_week
# 7 2020-01-08    190  2020      1    8            2
# 8 2020-01-09    205  2020      1    9            3
# 9 2020-01-10    215  2020      1   10            4

# %%
predictions
# Out:
# array([170.05, 181.85, 224.5 ])

# %%
df
# Out:
#          date  sales  year  month  day  day_of_week
# 0  2020-01-01    100  2020      1    1            2
# 1  2020-01-02    120  2020      1    2            3
# 2  2020-01-03    130  2020      1    3            4
# 3  2020-01-04    140  2020      1    4            5
# 4  2020-01-05    150  2020      1    5            6
# 5  2020-01-06    165  2020      1    6            0
# 6  2020-01-07    180  2020      1    7            1
# 7  2020-01-08    190  2020      1    8            2
# 8  2020-01-09    205  2020      1    9            3
# 9  2020-01-10    215  2020      1   10            4
# 10 2020-01-11    230  2020      1   11            5
# 11 2020-01-12    240  2020      1   12            6

# %%
data = pd.read_csv("sales_data.csv")

data['date'] = pd.to_datetime(data['date'])

# extract additional features
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data['day_of_week'] = data['date'].dt.dayofweek

# define the features and target
features = ['year', 'month', 'day', 'day_of_week']
target = 'sales'


# train the random forest model
model = RandomForestRegressor()
model.fit(data[features], data['sales'])
# Out:
# RandomForestRegressor()

# %%
#forecast_periods = st.sider("Select the number of forecast periods:", min_value=1, max_value=24, value=12, step=1)

forecast = model.predict(data.drop(['sales','date'],axis=1).tail(forecast_periods))

# %%
predictions = model.predict(test_df[features])

# %%
train = df[~df.isna()]

# %%
df[~df.isna().any(axis=1)]
# Out:
#          date  sales  year  month  day  day_of_week
# 0  2020-01-01    100  2020      1    1            2
# 1  2020-01-02    120  2020      1    2            3
# 2  2020-01-03    130  2020      1    3            4
# 3  2020-01-04    140  2020      1    4            5
# 4  2020-01-05    150  2020      1    5            6
# 5  2020-01-06    165  2020      1    6            0
# 6  2020-01-07    180  2020      1    7            1
# 7  2020-01-08    190  2020      1    8            2
# 8  2020-01-09    205  2020      1    9            3
# 9  2020-01-10    215  2020      1   10            4
# 10 2020-01-11    230  2020      1   11            5
# 11 2020-01-12    240  2020      1   12            6

# %%
#train data, those without na
train = data[~data.isna().any(axis=1)]
test = data[data.isna().any(axis=1)]

# %%
data = pd.read_csv("sales_data.csv")

data['date'] = pd.to_datetime(data['date'])

# extract additional features
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data['day_of_week'] = data['date'].dt.dayofweek

# define the features and target
features = ['year', 'month', 'day', 'day_of_week']
target = 'sales'

#train data, those without na
train = data[~data.isna().any(axis=1)]
test = data[data.isna().any(axis=1)]

# train the random forest model
model = RandomForestRegressor()
model.fit(train[features], train['sales'])
# Out:
# RandomForestRegressor()

# %%
forecast = model.predict(test[features])

# %%
foreca

# %%
len(forecast)
# Out:
# 10

# %%
data['sales'].iloc[-10:] = forecast
# Out:
# /tmp/ipykernel_25960/2999231051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sales'].iloc[-10:] = forecast

# %%
data = pd.read_csv("sales_data.csv")

# convert the date column to datetime
data['date'] = pd.to_datetime(data['date'])

# extract additional features
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data['day_of_week'] = data['date'].dt.dayofweek

# define the features and target
features = ['year', 'month', 'day', 'day_of_week']
target = 'sales'

#train data, those without na
train = data[~data.isna().any(axis=1)]
test = data[data.isna().any(axis=1)]

# train the random forest model
model = RandomForestRegressor()
model.fit(train[features], train['sales'])

forecast_periods = st.slider("Select the number of forecast periods:", min_value=1, max_value=24, value=10, step=1)

forecast = model.predict(test[features].tail(forecast_periods))

# %%
forecast_periods
# Out:
# 10

# %%
data['sales'].iloc[-10:] = forecast
# Out:
# /tmp/ipykernel_25960/2999231051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sales'].iloc[-10:] = forecast

# %%
data
# Out:
#          date   sales  year  month  day  day_of_week
# 0  2020-01-01  100.00  2020      1    1            2
# 1  2020-01-02  120.00  2020      1    2            3
# 2  2020-01-03  130.00  2020      1    3            4
# 3  2020-01-04  140.00  2020      1    4            5
# 4  2020-01-05  150.00  2020      1    5            6
# 5  2020-01-06  165.00  2020      1    6            0
# 6  2020-01-07  180.00  2020      1    7            1
# 7  2020-01-08  190.00  2020      1    8            2
# 8  2020-01-09  205.00  2020      1    9            3
# 9  2020-01-10  215.00  2020      1   10            4
# 10 2020-01-11  230.00  2020      1   11            5
# 11 2020-01-12  240.00  2020      1   12            6
# 12 2021-01-12  209.60  2021      1   12            1
# 13 2022-01-12  210.40  2022      1   12            2
# 14 2023-01-12  216.85  2023      1   12            3
# 15 2024-01-12  222.15  2024      1   12            4
# 16 2025-01-12  235.85  2025      1   12            6
# 17 2026-01-12  209.35  2026      1   12            0
# 18 2027-01-12  209.60  2027      1   12            1
# 19 2028-01-12  210.40  2028      1   12            2
# 20 2029-01-12  222.15  2029      1   12            4
# 21 2030-01-12  232.30  2030      1   12            5

# %%
data
# Out:
#          date  sales  year  month  day  day_of_week  previous_month_sales
# 0  2020-01-01  100.0  2020      1    1            2                 100.0
# 1  2020-01-02  120.0  2020      1    2            3                 100.0
# 2  2020-01-03  130.0  2020      1    3            4                 120.0
# 3  2020-01-04  140.0  2020      1    4            5                 130.0
# 4  2020-01-05  150.0  2020      1    5            6                 140.0
# 5  2020-01-06  165.0  2020      1    6            0                 150.0
# 6  2020-01-07  180.0  2020      1    7            1                 165.0
# 7  2020-01-08  190.0  2020      1    8            2                 180.0
# 8  2020-01-09  205.0  2020      1    9            3                 190.0
# 9  2020-01-10  215.0  2020      1   10            4                 205.0
# 10 2020-01-11  230.0  2020      1   11            5                 215.0
# 11 2020-01-12  240.0  2020      1   12            6                 230.0
# 12 2021-01-01    NaN  2021      1    1            4                 240.0
# 13 2021-01-02    NaN  2021      1    2            5                   NaN
# 14 2021-01-03    NaN  2021      1    3            6                   NaN
# 15 2021-01-04    NaN  2021      1    4            0                   NaN
# 16 2021-01-05    NaN  2021      1    5            1                   NaN
# 17 2021-01-06    NaN  2021      1    6            2                   NaN
# 18 2021-01-07    NaN  2021      1    7            3                   NaN
# 19 2021-01-08    NaN  2021      1    8            4                   NaN
# 20 2021-01-09    NaN  2021      1    9            5                   NaN
# 21 2021-01-10    NaN  2021      1   10            6                   NaN

# %%
data = pd.read_csv("sales_data.csv")
# convert the date column to datetime
data['date'] = pd.to_datetime(data['date'])

# extract additional features
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data['day_of_week'] = data['date'].dt.dayofweek
data['previous_month_sales'] = data['sales'].shift(1)
data['previous_month_sales'][0] = data['sales'][0]

# define the features and target
features = ['year', 'month', 'day', 'day_of_week','previous_month_sales']
target = 'sales'

#train data, those without na
train = data[~data.isna().any(axis=1)]
test = data[data.isna().any(axis=1)]
test['previous_month_sales'] = 240.0

# train the random forest model
model = RandomForestRegressor()
model.fit(train[features], train['sales'])


forecast = model.predict(test[features])

data['sales'].iloc[-10:] = forecast
# Out:
# /tmp/ipykernel_7453/2025588172.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['previous_month_sales'][0] = data['sales'][0]
# /tmp/ipykernel_7453/2025588172.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['previous_month_sales'] = 240.0
# /tmp/ipykernel_7453/2025588172.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sales'].iloc[-10:] = forecast

# %%
data = pd.read_csv("sales_data.csv")

# convert the date column to datetime
data['date'] = pd.to_datetime(data['date'])

# extract additional features
data['year'] = data['date'].dt.year
data['month'] = data['date'].dt.month
data['day'] = data['date'].dt.day
data['day_of_week'] = data['date'].dt.dayofweek

# define the features and target
features = ['year', 'month', 'day', 'day_of_week']
target = 'sales'

#train data, those without na
train = data[~data.isna().any(axis=1)]
test = data[data.isna().any(axis=1)]

# %%
# train the random forest model
model = RandomForestRegressor()
model.fit(train[features], train['sales'])

forecast_periods = st.slider("Select the number of forecast periods:", min_value=1, max_value=24, value=10, step=1)

forecast = model.predict(test[features])#.tail(forecast_periods))

data['sales'].iloc[-10:] = forecast
# Out:
# /tmp/ipykernel_7453/865089513.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sales'].iloc[-10:] = forecast

# %%
test[features].tail(forecast_periods)
# Out:
#     year  month  day  day_of_week
# 12  2021      1    1            4
# 13  2021      1    2            5
# 14  2021      1    3            6
# 15  2021      1    4            0
# 16  2021      1    5            1
# 17  2021      1    6            2
# 18  2021      1    7            3
# 19  2021      1    8            4
# 20  2021      1    9            5
# 21  2021      1   10            6

# %%
forecast
# Out:
# array([116.4 , 123.4 , 132.8 , 131.7 , 139.95, 158.75, 179.5 , 194.5 ,
#        212.4 , 223.4 ])

# %%
dates_forecast = data.iloc[-10:].date

# %%
dates_forecast.reset_index(drop=True,inplace=True)

# %%
forecast = pd.DataFrame(forecast, columns=['sales'])
forecast['date'] = dates_forecast

# %%
actual = pd.read_csv('actual_sales.csv')

# %%
actual['date'] = pd.to_datetime(actual['date'])

# %%
actual = actual[actual['date'].isin(forecast.date)]

# %%
actual.reset_index(drop=True,inplace=True)

# %%
comparison = actual.copy()

# %%
comparison['forecast_sales'] = forecast.sales

# %%
comparison['difference'] = comparison.sales - comparison.forecast_sales

# %%
comparison['alert'] = comparison['difference'].apply(lambda x: 'yes' if x > 100 else 'no')

# %%
comparison
# Out:
#         date  sales  forecast_sales  difference alert
# 0 2021-01-01    241          116.40      124.60   yes
# 1 2021-01-02    242          123.40      118.60   yes
# 2 2021-01-03    243          132.80      110.20   yes
# 3 2021-01-04    244          131.70      112.30   yes
# 4 2021-01-05    245          139.95      105.05   yes
# 5 2021-01-06    246          158.75       87.25    no
# 6 2021-01-07    247          179.50       67.50    no
# 7 2021-01-08    248          194.50       53.50    no
# 8 2021-01-09    249          212.40       36.60    no
# 9 2021-01-10    250          223.40       26.60    no

# %%
alert = comparison[comparison['alert']=='yes']

# %%
alert
# Out:
#         date  sales  forecast_sales  difference alert
# 0 2021-01-01    241          116.40      124.60   yes
# 1 2021-01-02    242          123.40      118.60   yes
# 2 2021-01-03    243          132.80      110.20   yes
# 3 2021-01-04    244          131.70      112.30   yes
# 4 2021-01-05    245          139.95      105.05   yes

# %%
# when will we run out of stock

# %%
stock = pd.read_csv('stock.csv')

# %%
stock
# Out:
#           date  sales   stock
# 0   01/01/2020  100.0  1000.0
# 1   01/02/2020  120.0   900.0
# 2   01/03/2020  130.0   780.0
# 3   01/04/2020  140.0   650.0
# 4   01/05/2020  150.0   510.0
# 5   01/06/2020  165.0   360.0
# 6   01/07/2020  180.0  1195.0
# 7   01/08/2020  190.0  1015.0
# 8   01/09/2020  205.0   825.0
# 9   01/10/2020  215.0   620.0
# 10  01/11/2020  230.0  1400.0
# 11  01/12/2020    NaN     NaN
# 12  01/01/2021    NaN     NaN
# 13  01/02/2021    NaN     NaN
# 14  01/03/2021    NaN     NaN
# 15  01/04/2021    NaN     NaN
# 16  01/05/2021    NaN     NaN
# 17  01/06/2021    NaN     NaN
# 18  01/07/2021    NaN     NaN
# 19  01/08/2021    NaN     NaN
# 20  01/09/2021    NaN     NaN
# 21  01/10/2021    NaN     NaN

# %%
forecast
# Out:
#     sales       date
# 0  116.40 2021-01-01
# 1  123.40 2021-01-02
# 2  132.80 2021-01-03
# 3  131.70 2021-01-04
# 4  139.95 2021-01-05
# 5  158.75 2021-01-06
# 6  179.50 2021-01-07
# 7  194.50 2021-01-08
# 8  212.40 2021-01-09
# 9  223.40 2021-01-10

# %%
stock_comparison = forecast.copy()

# %%
stock = stock.dropna()

# %%
last_stock = stock.iloc[-1].stock

# %%
stock_comparison
# Out:
#     sales       date
# 0  116.40 2021-01-01
# 1  123.40 2021-01-02
# 2  132.80 2021-01-03
# 3  131.70 2021-01-04
# 4  139.95 2021-01-05
# 5  158.75 2021-01-06
# 6  179.50 2021-01-07
# 7  194.50 2021-01-08
# 8  212.40 2021-01-09
# 9  223.40 2021-01-10

# %%
last_stock
# Out:
# 1400.0

# %%
stock_updated = []
for i in stock_comparison.sales:
    last_stock -= i 
    stock_updated.append(last_stock)

# %%
stock_updated
# Out:
# [1283.6,
#  1160.1999999999998,
#  1027.3999999999999,
#  895.6999999999998,
#  755.7499999999998,
#  596.9999999999998,
#  417.4999999999998,
#  222.99999999999977,
#  10.599999999999767,
#  -212.80000000000024]

# %%
stock_comparison['stock_updated'] = stock_updated

# %%
stock_comparison['stock_alert'] = stock_comparison['stock_updated'].apply(lambda x: 'yes' if x < 0 else 'no')
